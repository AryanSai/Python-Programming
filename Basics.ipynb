# %%
print("Hello World")
# Out:
# Hello World

# %%
if 5 > 2:
    print(2)
# Out:
# 2

# %%
print("Hello World"); print("Hello!")
# Out:
# Hello World
# Hello!

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %%
x = 3
print(type(x))
# Out:
# <class 'int'>

# %%
x = int(3)
print(type(x))
# Out:
# <class 'int'>

# %%
x = str(3)
print(type(x))
# Out:
# <class 'str'>

# %%
x = int("asb")
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x = int("asb")
#       2 print(type(x))
#
# ValueError: invalid literal for int() with base 10: 'asb'

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)

# %%
print('a' + 'b')
# Out:
# ab

# %%
print('a' , 'b')
# Out:
# a b

# %%
def trial():
    global x 
    x = 10

trial()
print(x)

def trial():
    y = 10
trial()
print(y)
# Out:
# 10
# 3

# %%
print(range(4))

for num in range(4):
    print(num)
# Out:
# range(0, 4)
# 0
# 1
# 2
# 3

# %%
x = 3
y = 1.2
z = 1j

# %%
import random

print(random.randrange(1,8))
# Out:
# 2

# %%
x = int(3)
y = int(1.2)
z = int("4")
zz = int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 y = int(1.2)
#       3 z = int("4")
# ----> 4 zz = int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
print("It's alright")
# Out:
# It's alright

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello
